# %%
# -*- coding: utf-8 -*-
"""GridSearchCV_PlantCLEF2013.ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1aZBAmZMLizQ6dA9POQHLiQ-a7AHY0Fxc
"""

import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn import svm
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import GridSearchCV
from sklearn.multiclass import OneVsRestClassifier
import time
import collections
from collections import defaultdict

# Commented out IPython magic to ensure Python compatibility.
#from google.colab import drive
#drive.mount('/gdrive/')
#%cd /gdrive/My\ Drive/artigo_plantas
#!ls

# %%
def multi_clf_metrics(arq_csv):

	# Cria X (features) e y (labels)
  especies = pd.read_csv(arq_csv, low_memory=False)
  X = np.array(especies.iloc[0:,0:2048])
  y = np.array(especies.iloc[0:,2048])		
  # Executa o PCA
  pca = PCA(.90)
  principal_components = pca.fit_transform(X)
  classifiers = {
					'SVC - (linear, ovo)': OneVsRestClassifier(svm.SVC(kernel='linear', degree=3, coef0=0.0,
											shrinking=True, probability=False, tol=0.001, cache_size=2000,
											class_weight=None, verbose=False, max_iter=-1,
											decision_function_shape='ovo', random_state=None))
}

  scoring = ['f1_micro']
  # Parametros para rodar com o grid search
  parameters = {"estimator__C" : [0.01, 0.1, 10], 'estimator__gamma':[0.0001, 0.001, 0.01]}
  results = []
  for name_clf, clf in classifiers.items():
    print('Executando classificador'+ name_clf)
    scores = GridSearchCV(clf, parameters,cv=5, scoring=scoring, refit='f1_micro', return_train_score=True, n_jobs=-1, verbose=51)
    result = scores.fit(principal_components,y)
    results.append(result) # done in case multiple clf's
  return result

# %%
results = multi_clf_metrics('plantclef2013_inception_V3.csv')
# Out:
# Executando classificadorSVC - (linear, ovo)
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# Memmapping (shape=(26077, 340), dtype=float64) to new file /var/folders/k2/7m7wfg6n6y5fylg_14w25lnc0000gp/T/joblib_memmapping_folder_11814_4905399370/11814-4394916104-9360f60ea38a4982a610ad75efffd025.pkl
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed: 34.1min
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed: 34.1min
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed: 34.1min
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed: 34.1min
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed: 34.3min
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed: 34.3min
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed: 34.4min
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed: 34.4min
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed: 67.9min
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed: 67.9min
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed: 68.2min
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed: 68.3min
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed: 68.3min
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed: 68.4min
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed: 68.5min
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed: 69.5min
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed: 103.6min
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed: 103.8min
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed: 104.1min
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed: 104.2min
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed: 104.3min
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed: 104.4min
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed: 104.4min
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed: 105.3min
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed: 138.7min
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed: 138.8min
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed: 139.1min
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed: 139.3min
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed: 139.5min
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed: 139.7min
# [Parallel(n_jobs=-1)]: Done  31 out of  45 | elapsed: 151.8min remaining: 68.6min
# [Parallel(n_jobs=-1)]: Done  32 out of  45 | elapsed: 153.5min remaining: 62.4min
# [Parallel(n_jobs=-1)]: Done  33 out of  45 | elapsed: 185.8min remaining: 67.6min
# [Parallel(n_jobs=-1)]: Done  34 out of  45 | elapsed: 185.8min remaining: 60.1min
# [Parallel(n_jobs=-1)]: Done  35 out of  45 | elapsed: 187.0min remaining: 53.4min
# [Parallel(n_jobs=-1)]: Done  36 out of  45 | elapsed: 188.4min remaining: 47.1min
# [Parallel(n_jobs=-1)]: Done  37 out of  45 | elapsed: 188.4min remaining: 40.7min
# [Parallel(n_jobs=-1)]: Done  38 out of  45 | elapsed: 189.3min remaining: 34.9min
# [Parallel(n_jobs=-1)]: Done  39 out of  45 | elapsed: 199.0min remaining: 30.6min
# [Parallel(n_jobs=-1)]: Done  40 out of  45 | elapsed: 200.0min remaining: 25.0min
# [Parallel(n_jobs=-1)]: Done  41 out of  45 | elapsed: 223.5min remaining: 21.8min
# [Parallel(n_jobs=-1)]: Done  42 out of  45 | elapsed: 224.2min remaining: 16.0min
# [Parallel(n_jobs=-1)]: Done  43 out of  45 | elapsed: 225.4min remaining: 10.5min
# [Parallel(n_jobs=-1)]: Done  45 out of  45 | elapsed: 226.7min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  45 out of  45 | elapsed: 226.7min finished

# %%
print(results.best_params_)
# Out:
# {'estimator__C': 0.1, 'estimator__gamma': 0.0001}
