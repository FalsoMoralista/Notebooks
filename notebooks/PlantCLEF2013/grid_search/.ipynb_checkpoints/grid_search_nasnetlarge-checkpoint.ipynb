# %%
# -*- coding: utf-8 -*-
"""GridSearchCV_PlantCLEF2013.ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1aZBAmZMLizQ6dA9POQHLiQ-a7AHY0Fxc
"""

import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn import svm
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import GridSearchCV
from sklearn.multiclass import OneVsRestClassifier
import time
import collections
from collections import defaultdict

# Commented out IPython magic to ensure Python compatibility.
#from google.colab import drive
#drive.mount('/gdrive/')
#%cd /gdrive/My\ Drive/artigo_plantas
#!ls

# %%
def multi_clf_metrics(arq_csv):

	# Cria X (features) e y (labels)
    especies = pd.read_csv(arq_csv, low_memory=False)

    if arq_csv == 'resnet50_features.csv' or arq_csv == 'resnet152v2_features.csv':
        X = np.array(especies.iloc[0:,0:2048])
        y = np.array(especies.iloc[0:,2048])		
    if arq_csv == 'nasnetlarge_features.csv':
        X = np.array(especies.iloc[0:,0:4032])
        y = np.array(especies.iloc[0:,4032])		
 # Executa o PCA
    pca = PCA(.90)
    principal_components = pca.fit_transform(X)
 # 'SVC - (linear, ovr)': OneVsRestClassifier(svm.SVC(kernel='linear', degree=3, coef0=0.0,
#											shrinking=True, probability=False, tol=0.001, cache_size=500,
#											class_weight=None, verbose=False, max_iter=-1,
#											decision_function_shape='ovr', random_state=None)),					'SVC - (linear, ovo)': svm.SVC(kernel='linear', degree=3, coef0=0.0,
#											shrinking=True, probability=False, tol=0.001, cache_size=500,
#											class_weight=None, verbose=False, max_iter=-1,
#											decision_function_shape='ovo', random_state=None),					'SVC - (polynomial, ovo)': svm.SVC(kernel='poly', degree=3, coef0=0.0,
#											shrinking=True, probability=False, tol=0.001, cache_size=500,
#											class_weight=None, verbose=False, max_iter=-1,
#											decision_function_shape='ovo', random_state=None),
#					'SVC - (sigmoid, ovr)': OneVsRestClassifier(svm.SVC(kernel='sigmoid', degree=3,coef0=0.0,
#											shrinking=True, probability=False, tol=0.001, cache_size=500,
#											class_weight=None, verbose=False, max_iter=-1,
#											decision_function_shape='ovr', random_state=None)),
#					'SVC - (sigmoid, ovo)': svm.SVC(kernel='sigmoid', degree=3, coef0=0.0,
#											shrinking=True, probability=False, tol=0.001, cache_size=500,
#											class_weight=None, verbose=False, max_iter=-1,
#											decision_function_shape='ovo', random_state=None)
    classifiers = {
					'SVC - (linear, ovr)': OneVsRestClassifier(svm.SVC(kernel='linear', degree=3, coef0=0.0,
											shrinking=True, probability=False, tol=0.001, cache_size=2000,
											class_weight=None, verbose=False, max_iter=-1,
											decision_function_shape='ovr', random_state=None))
    }

    scoring = ['f1_micro']
  # Parametros para rodar com o grid search
    parameters = {"estimator__C" : [0.01, 0.1, 10], 'estimator__gamma':[0.0001, 0.001, 0.01]}
    results = []
    for name_clf, clf in classifiers.items():
        print('Executando classificador'+ name_clf)
        scores = GridSearchCV(clf, parameters,cv=5, scoring=scoring, refit='f1_micro', return_train_score=True, n_jobs=-1, verbose=51)
        result = scores.fit(principal_components,y)
        results.append(result)
    return result

# %%
results = multi_clf_metrics('nasnetlarge_features.csv')
# Out:
# Executando classificadorSVC - (linear, ovr)
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# Memmapping (shape=(26077, 422), dtype=float64) to new file /var/folders/k2/7m7wfg6n6y5fylg_14w25lnc0000gp/T/joblib_memmapping_folder_23372_7722559916/23372-112026650328-0c7cc8961e604276a39d0988e2504875.pkl
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed: 43.9min
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed: 43.9min
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed: 44.1min
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed: 44.1min
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed: 44.2min
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed: 44.2min
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed: 44.3min
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed: 44.5min
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed: 87.6min
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed: 87.7min
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed: 87.8min
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed: 87.8min
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed: 88.0min
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed: 88.1min
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed: 88.3min
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed: 89.1min
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed: 133.0min
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed: 133.3min
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed: 133.3min
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed: 133.5min
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed: 133.6min
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed: 133.9min
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed: 133.9min
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed: 134.6min
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed: 178.0min
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed: 178.3min
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed: 178.5min
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed: 178.6min
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed: 178.8min
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed: 179.4min
# [Parallel(n_jobs=-1)]: Done  31 out of  45 | elapsed: 182.1min remaining: 82.2min
# [Parallel(n_jobs=-1)]: Done  32 out of  45 | elapsed: 183.4min remaining: 74.5min
# [Parallel(n_jobs=-1)]: Done  33 out of  45 | elapsed: 226.2min remaining: 82.3min
# [Parallel(n_jobs=-1)]: Done  34 out of  45 | elapsed: 226.4min remaining: 73.3min
# [Parallel(n_jobs=-1)]: Done  35 out of  45 | elapsed: 226.8min remaining: 64.8min
# [Parallel(n_jobs=-1)]: Done  36 out of  45 | elapsed: 226.9min remaining: 56.7min
# [Parallel(n_jobs=-1)]: Done  37 out of  45 | elapsed: 227.0min remaining: 49.1min
# [Parallel(n_jobs=-1)]: Done  38 out of  45 | elapsed: 227.7min remaining: 41.9min
# [Parallel(n_jobs=-1)]: Done  39 out of  45 | elapsed: 230.0min remaining: 35.4min
# [Parallel(n_jobs=-1)]: Done  40 out of  45 | elapsed: 230.9min remaining: 28.9min
# [Parallel(n_jobs=-1)]: Done  41 out of  45 | elapsed: 261.8min remaining: 25.5min
# [Parallel(n_jobs=-1)]: Done  42 out of  45 | elapsed: 262.4min remaining: 18.7min
# [Parallel(n_jobs=-1)]: Done  43 out of  45 | elapsed: 262.9min remaining: 12.2min
# [Parallel(n_jobs=-1)]: Done  45 out of  45 | elapsed: 263.0min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  45 out of  45 | elapsed: 263.0min finished

# %%
print(results.best_params_)
# Out:
# {'estimator__C': 0.1, 'estimator__gamma': 0.0001}
