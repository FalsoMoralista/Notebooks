# %%
# -*- coding: utf-8 -*-
"""GridSearchCV_PlantCLEF2013.ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1aZBAmZMLizQ6dA9POQHLiQ-a7AHY0Fxc
"""

import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn import svm
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import GridSearchCV
from sklearn.multiclass import OneVsRestClassifier
import time
import collections
from collections import defaultdict

# Commented out IPython magic to ensure Python compatibility.
#from google.colab import drive
#drive.mount('/gdrive/')
#%cd /gdrive/My\ Drive/artigo_plantas
#!ls

# %%
def multi_clf_metrics(arq_csv):

	# Cria X (features) e y (labels)
  especies = pd.read_csv(arq_csv, low_memory=False)
  X = np.array(especies.iloc[2:,0:4096])
  y = np.array(especies.iloc[2:,4096])		
  # Executa o PCA
  pca = PCA(.90)
  principal_components = pca.fit_transform(X)
 # 'SVC - (linear, ovr)': OneVsRestClassifier(svm.SVC(kernel='linear', degree=3, coef0=0.0,
#											shrinking=True, probability=False, tol=0.001, cache_size=500,
#											class_weight=None, verbose=False, max_iter=-1,
#											decision_function_shape='ovr', random_state=None)),					'SVC - (linear, ovo)': svm.SVC(kernel='linear', degree=3, coef0=0.0,
#											shrinking=True, probability=False, tol=0.001, cache_size=500,
#											class_weight=None, verbose=False, max_iter=-1,
#											decision_function_shape='ovo', random_state=None),					'SVC - (polynomial, ovo)': svm.SVC(kernel='poly', degree=3, coef0=0.0,
#											shrinking=True, probability=False, tol=0.001, cache_size=500,
#											class_weight=None, verbose=False, max_iter=-1,
#											decision_function_shape='ovo', random_state=None),
#					'SVC - (sigmoid, ovr)': OneVsRestClassifier(svm.SVC(kernel='sigmoid', degree=3,coef0=0.0,
#											shrinking=True, probability=False, tol=0.001, cache_size=500,
#											class_weight=None, verbose=False, max_iter=-1,
#											decision_function_shape='ovr', random_state=None)),
#					'SVC - (sigmoid, ovo)': svm.SVC(kernel='sigmoid', degree=3, coef0=0.0,
#											shrinking=True, probability=False, tol=0.001, cache_size=500,
#											class_weight=None, verbose=False, max_iter=-1,
#											decision_function_shape='ovo', random_state=None)
  classifiers = {
					'SVC - (polynomial, ovr)': OneVsRestClassifier(svm.SVC(kernel='poly', degree=3, coef0=0.0,
											shrinking=True, probability=False, tol=0.001, cache_size=2000,
											class_weight=None, verbose=False, max_iter=-1,
											decision_function_shape='ovr', random_state=None))
}

  scoring = ['f1_micro']
  # Parametros para rodar com o grid search
  parameters = {"estimator__C" : [0.01, 0.1, 10], 'estimator__gamma':[0.0001, 0.001, 0.01]}
  results = []
  f = open('gd_srch_results_'+arq_csv,'w')
  f.write('classifier name,'+'best parameters,'+'all results\n')
  f.close()
  for name_clf, clf in classifiers.items():
    print('Executando classificador'+ name_clf)
    scores = GridSearchCV(clf, parameters,cv=5, scoring=scoring, refit='f1_micro', return_train_score=True, n_jobs=-1, verbose=51)
    result = scores.fit(principal_components,y)
    results.append(result)
#    print('Melhor configuração: '+result.best_params_)
#    f = open('gd_srch_results_'+arq_csv,'w')
#    f.write(name_clf+',')
#    f.write(result.best_params_+',')
#    f.write(result+'\n')
#    f.close()
  return result

# %%
results = multi_clf_metrics('plantclef2013_vgg16.csv')
# Out:
# Executando classificadorSVC - (polynomial, ovr)
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# Memmapping (shape=(26077, 527), dtype=float64) to new file /var/folders/k2/7m7wfg6n6y5fylg_14w25lnc0000gp/T/joblib_memmapping_folder_9244_4927505988/9244-115100386920-fdf5f14b40d941dfacfea4f6b6ea1465.pkl
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed: 35.2min
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed: 35.5min
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed: 35.6min
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed: 35.7min
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed: 35.9min
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed: 105.4min
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed: 106.9min
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed: 107.1min
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed: 143.9min
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed: 144.6min
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed: 158.2min
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed: 175.4min
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed: 176.1min
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed: 177.1min
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed: 195.7min
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed: 196.0min
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed: 208.4min
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed: 225.6min
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed: 243.7min
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed: 246.0min
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed: 297.5min
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed: 299.8min
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed: 320.5min
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed: 321.7min
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed: 335.5min
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed: 365.7min
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed: 384.1min
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed: 387.1min
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed: 427.3min
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed: 429.6min
# [Parallel(n_jobs=-1)]: Done  31 out of  45 | elapsed: 439.6min remaining: 198.5min
# [Parallel(n_jobs=-1)]: Done  32 out of  45 | elapsed: 442.7min remaining: 179.9min
# [Parallel(n_jobs=-1)]: Done  33 out of  45 | elapsed: 443.0min remaining: 161.1min
# [Parallel(n_jobs=-1)]: Done  34 out of  45 | elapsed: 471.5min remaining: 152.6min
# [Parallel(n_jobs=-1)]: Done  35 out of  45 | elapsed: 489.4min remaining: 139.8min
# [Parallel(n_jobs=-1)]: Done  36 out of  45 | elapsed: 525.0min remaining: 131.3min
# [Parallel(n_jobs=-1)]: Done  37 out of  45 | elapsed: 569.0min remaining: 123.0min
# [Parallel(n_jobs=-1)]: Done  38 out of  45 | elapsed: 572.1min remaining: 105.4min
# [Parallel(n_jobs=-1)]: Done  39 out of  45 | elapsed: 582.6min remaining: 89.6min
# [Parallel(n_jobs=-1)]: Done  40 out of  45 | elapsed: 583.5min remaining: 72.9min
# [Parallel(n_jobs=-1)]: Done  41 out of  45 | elapsed: 585.3min remaining: 57.1min
# [Parallel(n_jobs=-1)]: Done  42 out of  45 | elapsed: 602.2min remaining: 43.0min
# [Parallel(n_jobs=-1)]: Done  43 out of  45 | elapsed: 612.6min remaining: 28.5min
# [Parallel(n_jobs=-1)]: Done  45 out of  45 | elapsed: 652.8min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  45 out of  45 | elapsed: 652.8min finished

# %%
f = open('gd_srch_results_plantclef2013_vgg16.csv','w')
f.write(results.best_params_',')
f.write(results+'\n')
f.close()
# Out:
#   File "<ipython-input-12-f5c1aa2caace>", line 2
#     f.write(results.best_params_',')
#                                   ^
# SyntaxError: invalid syntax

# %%
print(results.best_params_)
# Out:
# {'estimator__C': 0.01, 'estimator__gamma': 0.01}
